# %% [markdown]
# # The Algorithm Design Manual: Chapter 01 - Introduction to Algorithm Design
#
# Use this notebook for original notes, solutions, code experiments, and proof attempts. Keep copied textbook text out of committed cells.

# %% [markdown]
# ## Chapter Notes
#
# ### Main Ideas
#
# -
#
# ### Definitions
#
# | Term | Meaning |
# | --- | --- |
# | | |
#
# ### Open Questions
#
# -

# %% [markdown]
# ## 1-1: Arithmetic counterexample: sum vs minimum
#
# - Source: The Algorithm Design Manual
# - Problem: 1-1
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: counterexample
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-1 statement](../../problem-images.local/algorithm-design-manual/1-1.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-1.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-1.cpp -o /tmp/algorithm-design-manual-1-1
# /tmp/algorithm-design-manual-1-1

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-2: Arithmetic counterexample: product vs minimum
#
# - Source: The Algorithm Design Manual
# - Problem: 1-2
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: counterexample
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-2 statement](../../problem-images.local/algorithm-design-manual/1-2.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-2.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-2.cpp -o /tmp/algorithm-design-manual-1-2
# /tmp/algorithm-design-manual-1-2

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-3: Road-network counterexample: fastest vs shortest
#
# - Source: The Algorithm Design Manual
# - Problem: 1-3
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: counterexample
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-3 statement](../../problem-images.local/algorithm-design-manual/1-3.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-3.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-3.cpp -o /tmp/algorithm-design-manual-1-3
# /tmp/algorithm-design-manual-1-3

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-4: Road-network counterexample: shortest vs fewest turns
#
# - Source: The Algorithm Design Manual
# - Problem: 1-4
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: counterexample
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-4 statement](../../problem-images.local/algorithm-design-manual/1-4.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-4.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-4.cpp -o /tmp/algorithm-design-manual-1-4
# /tmp/algorithm-design-manual-1-4

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-5: Knapsack greedy counterexamples
#
# - Source: The Algorithm Design Manual
# - Problem: 1-5
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 4
# - Tags: counterexample;knapsack;greedy
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-5 statement](../../problem-images.local/algorithm-design-manual/1-5.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-5.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-5.cpp -o /tmp/algorithm-design-manual-1-5
# /tmp/algorithm-design-manual-1-5

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-6: Set cover greedy counterexample
#
# - Source: The Algorithm Design Manual
# - Problem: 1-6
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: counterexample;set-cover;greedy
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-6 statement](../../problem-images.local/algorithm-design-manual/1-6.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-6.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-6.cpp -o /tmp/algorithm-design-manual-1-6
# /tmp/algorithm-design-manual-1-6

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-7: Maximum clique greedy counterexample
#
# - Source: The Algorithm Design Manual
# - Problem: 1-7
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: counterexample;graphs;greedy
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-7 statement](../../problem-images.local/algorithm-design-manual/1-7.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-7.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-7.cpp -o /tmp/algorithm-design-manual-1-7
# /tmp/algorithm-design-manual-1-7

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-8: Recursive multiplication correctness proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-8
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: correctness;recursion
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-8 statement](../../problem-images.local/algorithm-design-manual/1-8.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-8.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-8.cpp -o /tmp/algorithm-design-manual-1-8
# /tmp/algorithm-design-manual-1-8

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-9: Horner evaluation correctness proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-9
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: correctness;polynomials
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-9 statement](../../problem-images.local/algorithm-design-manual/1-9.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-9.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-9.cpp -o /tmp/algorithm-design-manual-1-9
# /tmp/algorithm-design-manual-1-9

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-10: Bubblesort correctness proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-10
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: correctness;sorting
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-10 statement](../../problem-images.local/algorithm-design-manual/1-10.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-10.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-10.cpp -o /tmp/algorithm-design-manual-1-10
# /tmp/algorithm-design-manual-1-10

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-11: Euclid algorithm correctness proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-11
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: correctness;number-theory
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-11 statement](../../problem-images.local/algorithm-design-manual/1-11.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-11.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-11.cpp -o /tmp/algorithm-design-manual-1-11
# /tmp/algorithm-design-manual-1-11

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-12: Sum of integers induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-12
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-12 statement](../../problem-images.local/algorithm-design-manual/1-12.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-12.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-12.cpp -o /tmp/algorithm-design-manual-1-12
# /tmp/algorithm-design-manual-1-12

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-13: Sum of squares induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-13
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-13 statement](../../problem-images.local/algorithm-design-manual/1-13.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-13.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-13.cpp -o /tmp/algorithm-design-manual-1-13
# /tmp/algorithm-design-manual-1-13

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-14: Sum of cubes induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-14
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-14 statement](../../problem-images.local/algorithm-design-manual/1-14.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-14.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-14.cpp -o /tmp/algorithm-design-manual-1-14
# /tmp/algorithm-design-manual-1-14

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-15: Product-sum identity induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-15
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-15 statement](../../problem-images.local/algorithm-design-manual/1-15.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-15.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-15.cpp -o /tmp/algorithm-design-manual-1-15
# /tmp/algorithm-design-manual-1-15

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-16: Geometric series induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-16
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: induction;series
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-16 statement](../../problem-images.local/algorithm-design-manual/1-16.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-16.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-16.cpp -o /tmp/algorithm-design-manual-1-16
# /tmp/algorithm-design-manual-1-16

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-17: Telescoping reciprocal induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-17
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction;series
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-17 statement](../../problem-images.local/algorithm-design-manual/1-17.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-17.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-17.cpp -o /tmp/algorithm-design-manual-1-17
# /tmp/algorithm-design-manual-1-17

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-18: Divisibility induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-18
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction;number-theory
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-18 statement](../../problem-images.local/algorithm-design-manual/1-18.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-18.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-18.cpp -o /tmp/algorithm-design-manual-1-18
# /tmp/algorithm-design-manual-1-18

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-19: Tree edge-count induction proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-19
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction;graphs
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-19 statement](../../problem-images.local/algorithm-design-manual/1-19.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-19.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-19.cpp -o /tmp/algorithm-design-manual-1-19
# /tmp/algorithm-design-manual-1-19

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-20: Sum of cubes identity proof
#
# - Source: The Algorithm Design Manual
# - Problem: 1-20
# - Kind: proof
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: induction;series
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-20 statement](../../problem-images.local/algorithm-design-manual/1-20.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-20.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-20.cpp -o /tmp/algorithm-design-manual-1-20
# /tmp/algorithm-design-manual-1-20

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-21: Estimate owned and library pages
#
# - Source: The Algorithm Design Manual
# - Problem: 1-21
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-21 statement](../../problem-images.local/algorithm-design-manual/1-21.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-21.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-21.cpp -o /tmp/algorithm-design-manual-1-21
# /tmp/algorithm-design-manual-1-21

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-22: Estimate textbook word count
#
# - Source: The Algorithm Design Manual
# - Problem: 1-22
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-22 statement](../../problem-images.local/algorithm-design-manual/1-22.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-22.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-22.cpp -o /tmp/algorithm-design-manual-1-22
# /tmp/algorithm-design-manual-1-22

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-23: Mental estimate for one million seconds
#
# - Source: The Algorithm Design Manual
# - Problem: 1-23
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-23 statement](../../problem-images.local/algorithm-design-manual/1-23.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-23.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-23.cpp -o /tmp/algorithm-design-manual-1-23
# /tmp/algorithm-design-manual-1-23

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-24: Estimate US cities and towns
#
# - Source: The Algorithm Design Manual
# - Problem: 1-24
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-24 statement](../../problem-images.local/algorithm-design-manual/1-24.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-24.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-24.cpp -o /tmp/algorithm-design-manual-1-24
# /tmp/algorithm-design-manual-1-24

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-25: Estimate Mississippi River outflow
#
# - Source: The Algorithm Design Manual
# - Problem: 1-25
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-25 statement](../../problem-images.local/algorithm-design-manual/1-25.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-25.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-25.cpp -o /tmp/algorithm-design-manual-1-25
# /tmp/algorithm-design-manual-1-25

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-26: Estimate chain restaurant locations
#
# - Source: The Algorithm Design Manual
# - Problem: 1-26
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-26 statement](../../problem-images.local/algorithm-design-manual/1-26.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-26.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-26.cpp -o /tmp/algorithm-design-manual-1-26
# /tmp/algorithm-design-manual-1-26

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-27: Estimate bathtub draining time
#
# - Source: The Algorithm Design Manual
# - Problem: 1-27
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-27 statement](../../problem-images.local/algorithm-design-manual/1-27.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-27.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-27.cpp -o /tmp/algorithm-design-manual-1-27
# /tmp/algorithm-design-manual-1-27

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-28: Estimate storage and CPU time scales
#
# - Source: The Algorithm Design Manual
# - Problem: 1-28
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: estimation;systems
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-28 statement](../../problem-images.local/algorithm-design-manual/1-28.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-28.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-28.cpp -o /tmp/algorithm-design-manual-1-28
# /tmp/algorithm-design-manual-1-28

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-29: Compare sorting runtime growth
#
# - Source: The Algorithm Design Manual
# - Problem: 1-29
# - Kind: exercise
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 4
# - Tags: estimation;sorting;complexity
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-29 statement](../../problem-images.local/algorithm-design-manual/1-29.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-29.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-29.cpp -o /tmp/algorithm-design-manual-1-29
# /tmp/algorithm-design-manual-1-29

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-30: Implement and compare TSP heuristics
#
# - Source: The Algorithm Design Manual
# - Problem: 1-30
# - Kind: project
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: implementation;tsp;heuristics
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-30 statement](../../problem-images.local/algorithm-design-manual/1-30.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-30.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-30.cpp -o /tmp/algorithm-design-manual-1-30
# /tmp/algorithm-design-manual-1-30

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-31: Implement Lotto coverage search
#
# - Source: The Algorithm Design Manual
# - Problem: 1-31
# - Kind: project
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: implementation;set-cover
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-31 statement](../../problem-images.local/algorithm-design-manual/1-31.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-31.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-31.cpp -o /tmp/algorithm-design-manual-1-31
# /tmp/algorithm-design-manual-1-31

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-32: Integer division without division or multiplication
#
# - Source: The Algorithm Design Manual
# - Problem: 1-32
# - Kind: interview
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: interview;arithmetic
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-32 statement](../../problem-images.local/algorithm-design-manual/1-32.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-32.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-32.cpp -o /tmp/algorithm-design-manual-1-32
# /tmp/algorithm-design-manual-1-32

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-33: Minimum races for top three horses
#
# - Source: The Algorithm Design Manual
# - Problem: 1-33
# - Kind: interview
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 5
# - Tags: interview;reasoning
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-33 statement](../../problem-images.local/algorithm-design-manual/1-33.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-33.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-33.cpp -o /tmp/algorithm-design-manual-1-33
# /tmp/algorithm-design-manual-1-33

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-34: Estimate worldwide piano tuners
#
# - Source: The Algorithm Design Manual
# - Problem: 1-34
# - Kind: interview
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: interview;estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-34 statement](../../problem-images.local/algorithm-design-manual/1-34.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-34.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-34.cpp -o /tmp/algorithm-design-manual-1-34
# /tmp/algorithm-design-manual-1-34

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-35: Estimate US gas stations
#
# - Source: The Algorithm Design Manual
# - Problem: 1-35
# - Kind: interview
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: interview;estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-35 statement](../../problem-images.local/algorithm-design-manual/1-35.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-35.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-35.cpp -o /tmp/algorithm-design-manual-1-35
# /tmp/algorithm-design-manual-1-35

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-36: Estimate hockey rink ice weight
#
# - Source: The Algorithm Design Manual
# - Problem: 1-36
# - Kind: interview
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: interview;estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-36 statement](../../problem-images.local/algorithm-design-manual/1-36.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-36.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-36.cpp -o /tmp/algorithm-design-manual-1-36
# /tmp/algorithm-design-manual-1-36

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-37: Estimate US road mileage
#
# - Source: The Algorithm Design Manual
# - Problem: 1-37
# - Kind: interview
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: interview;estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-37 statement](../../problem-images.local/algorithm-design-manual/1-37.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-37.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-37.cpp -o /tmp/algorithm-design-manual-1-37
# /tmp/algorithm-design-manual-1-37

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 1-38: Estimate random phone-book search attempts
#
# - Source: The Algorithm Design Manual
# - Problem: 1-38
# - Kind: interview
# - Status: Not started
# - Page/ref: Section 1.10
# - Difficulty: 3
# - Tags: interview;estimation
#
# ### Problem Reference
#
# Local question image, when available:
#
# ![Problem 1-38 statement](../../problem-images.local/algorithm-design-manual/1-38.svg)
#
# If the image is missing, generate local question images from your ignored local statements file.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-38.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-38.cpp -o /tmp/algorithm-design-manual-1-38
# /tmp/algorithm-design-manual-1-38

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:
