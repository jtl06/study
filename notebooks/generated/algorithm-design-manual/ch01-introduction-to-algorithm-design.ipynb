# %% [markdown]
# # The Algorithm Design Manual: Chapter 01 - Introduction to Algorithm Design
#
# Use this notebook for notes, solutions, code experiments, and proof attempts.

# %% [markdown]
# ## Chapter Notes
#
# ### Main Ideas
#
# -
#
# ### Definitions
#
# | Term | Meaning |
# | --- | --- |
# | | |
#
# ### Open Questions
#
# -

# %% [markdown]
# ## 1-1: Arithmetic counterexample: sum vs minimum
#
# ### Problem Statement
#
# [3] Show that a + b can be less than min( a, b ).

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-1.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-1.cpp -o /tmp/algorithm-design-manual-1-1
# /tmp/algorithm-design-manual-1-1

# %% [markdown]
# ## 1-2: Arithmetic counterexample: product vs minimum
#
# ### Problem Statement
#
# [3] Show that a × b can be less than min( a, b ).

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-2.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-2.cpp -o /tmp/algorithm-design-manual-1-2
# /tmp/algorithm-design-manual-1-2

# %% [markdown]
# ## 1-3: Road-network counterexample: fastest vs shortest
#
# ### Problem Statement
#
# [5] Design/draw a road network with two points a and b such that the fastest route between a and b is not the shortest route.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-3.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-3.cpp -o /tmp/algorithm-design-manual-1-3
# /tmp/algorithm-design-manual-1-3

# %% [markdown]
# ## 1-4: Road-network counterexample: shortest vs fewest turns
#
# ### Problem Statement
#
# [5] Design/draw a road network with two points a and b such that the shortest route between a and b is not the route with the fewest turns.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-4.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-4.cpp -o /tmp/algorithm-design-manual-1-4
# /tmp/algorithm-design-manual-1-4

# %% [markdown]
# ## 1-5(a): Knapsack counterexample: first-fit order
#
# ### Problem Statement
#
# [4] The knapsack problem is as follows: given a set of integers S = { s 1, s 2,..., s n }, and a target number T, find a subset of S that adds up exactly to T. For ex- ample, there exists a subset within S = { 1, 2, 5, 9, 10 } that adds up to T = 22 but not T = 23. Find counterexamples to each of the following algorithms for the knapsack prob- lem. That is, give an S and T where the algorithm does not find a solution that leaves the knapsack completely full, even though a full-knapsack solution exists. (a) Put the elements of S in the knapsack in left to right order if they fit, that is, the first-fit algorithm.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-5-a.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-5-a.cpp -o /tmp/algorithm-design-manual-1-5-a
# /tmp/algorithm-design-manual-1-5-a

# %% [markdown]
# ## 1-5(b): Knapsack counterexample: smallest first
#
# ### Problem Statement
#
# [4] The knapsack problem is as follows: given a set of integers S = { s 1, s 2,..., s n }, and a target number T, find a subset of S that adds up exactly to T. For ex- ample, there exists a subset within S = { 1, 2, 5, 9, 10 } that adds up to T = 22 but not T = 23. Find counterexamples to each of the following algorithms for the knapsack prob- lem. That is, give an S and T where the algorithm does not find a solution that leaves the knapsack completely full, even though a full-knapsack solution exists. (b) Put the elements of S in the knapsack from smallest to largest, that is, the best-fit algorithm.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-5-b.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-5-b.cpp -o /tmp/algorithm-design-manual-1-5-b
# /tmp/algorithm-design-manual-1-5-b

# %% [markdown]
# ## 1-5(c): Knapsack counterexample: largest first
#
# ### Problem Statement
#
# [4] The knapsack problem is as follows: given a set of integers S = { s 1, s 2,..., s n }, and a target number T, find a subset of S that adds up exactly to T. For ex- ample, there exists a subset within S = { 1, 2, 5, 9, 10 } that adds up to T = 22 but not T = 23. Find counterexamples to each of the following algorithms for the knapsack prob- lem. That is, give an S and T where the algorithm does not find a solution that leaves the knapsack completely full, even though a full-knapsack solution exists. (c) Put the elements of S in the knapsack from largest to smallest.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-5-c.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-5-c.cpp -o /tmp/algorithm-design-manual-1-5-c
# /tmp/algorithm-design-manual-1-5-c

# %% [markdown]
# ## 1-6: Set cover greedy counterexample
#
# ### Problem Statement
#
# [5] The set cover problem is as follows: given a set S of subsets S 1,..., S m of the universal set U = { 1,..., n }, find the smallest subset of subsets T ⊆ S such that ∪ t i ∈ T t i = U. For example, consider the subsets S 1 = { 1, 3, 5 }, S 2 = { 2, 4 }, S 3 = { 1, 4 }, and S 4 = { 2, 5 }. The set cover of { 1,..., 5 } would then be S 1 and S 2. Find a counterexample for the following algorithm: Select the largest subset for the cover, and then delete all its elements from the universal set. Repeat by adding the subset containing the largest number of uncovered elements until all are covered.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-6.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-6.cpp -o /tmp/algorithm-design-manual-1-6
# /tmp/algorithm-design-manual-1-6

# %% [markdown]
# ## 1-7: Maximum clique greedy counterexample
#
# ### Problem Statement
#
# [5] The maximum clique problem in a graph G = ( V, E ) asks for the largest subset C of vertices V such that there is an edge in E between every pair of vertices in C. Find a counterexample for the following algorithm: Sort the vertices of G from highest to lowest degree. Considering the vertices in order 28 CHAPTER 1. INTRODUCTION TO ALGORITHM DESIGN of degree, for each vertex add it to the clique if it is a neighbor of all vertices currently in the clique. Repeat until all vertices have been considered. Proofs of Correctness

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-7.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-7.cpp -o /tmp/algorithm-design-manual-1-7
# /tmp/algorithm-design-manual-1-7

# %% [markdown]
# ## 1-8: Recursive multiplication correctness proof
#
# ### Problem Statement
#
# [3] Prove the correctness of the following recursive algorithm to multiply two natural numbers, for all integer constants c ≥ 2. Multiply( y, z ) if z = 0 then return(0) else return(Multiply( cy, z/c ) + y · ( z mod c ))

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-8.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-8.cpp -o /tmp/algorithm-design-manual-1-8
# /tmp/algorithm-design-manual-1-8

# %% [markdown]
# ## 1-9: Horner evaluation correctness proof
#
# ### Problem Statement
#
# [3] Prove the correctness of the following algorithm for evaluating a polynomial a n n − 1 n x + a n − 1 x + · · · + a 1 x + a 0. Horner( a, x ) p = a n for i from n − 1 to 0 p = p · x + a i return p

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-9.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-9.cpp -o /tmp/algorithm-design-manual-1-9
# /tmp/algorithm-design-manual-1-9

# %% [markdown]
# ## 1-10: Bubblesort correctness proof
#
# ### Problem Statement
#
# [3] Prove the correctness of the following sorting algorithm. Bubblesort ( A ) for i from n to 1 for j from 1 to i − 1 if ( A [ j ] > A [ j + 1]) swap the values of A [ j ] and A [ j + 1]

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-10.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-10.cpp -o /tmp/algorithm-design-manual-1-10
# /tmp/algorithm-design-manual-1-10

# %% [markdown]
# ## 1-11: Euclid algorithm correctness proof
#
# ### Problem Statement
#
# [5] The greatest common divisor of positive integers x and y is the largest integer d such that d divides x and d divides y. Euclid’s algorithm to compute gcd( x, y ) where x > y reduces the task to a smaller problem: gcd( x, y ) = gcd( y, x mod y ) Prove that Euclid’s algorithm is correct. Induction

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-11.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-11.cpp -o /tmp/algorithm-design-manual-1-11
# /tmp/algorithm-design-manual-1-11

# %% [markdown]
# ## 1-12: Sum of integers induction proof
#
# ### Problem Statement
#
# n [3] Prove that i = n ( n + 1) / 2 for n 0, by induction. i =1 ≥ n 2

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-12.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-12.cpp -o /tmp/algorithm-design-manual-1-12
# /tmp/algorithm-design-manual-1-12

# %% [markdown]
# ## 1-13: Sum of squares induction proof
#
# ### Problem Statement
#
# [3] Prove that i = n ( n + 1)(2 n + 1) / 6 for n i =1 ≥ 0, by induction. n 3 2 2

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-13.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-13.cpp -o /tmp/algorithm-design-manual-1-13
# /tmp/algorithm-design-manual-1-13

# %% [markdown]
# ## 1-14: Sum of cubes induction proof
#
# ### Problem Statement
#
# [3] Prove that i = n ( n + 1) / 4 for n ≥ 0, by induction. i =1

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-14.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-14.cpp -o /tmp/algorithm-design-manual-1-14
# /tmp/algorithm-design-manual-1-14

# %% [markdown]
# ## 1-15: Product-sum identity induction proof
#
# ### Problem Statement
#
# [3] Prove that n i ( i + 1)( i + 2) = n ( n + 1)( n + 2)( n + 3) / 4 i =1

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-15.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-15.cpp -o /tmp/algorithm-design-manual-1-15
# /tmp/algorithm-design-manual-1-15

# %% [markdown]
# ## 1-16: Geometric series induction proof
#
# ### Problem Statement
#
# [5] Prove by induction on n ≥ 1 that for every a = 1, n n +1 a i − 1 a = a − 1 i =0 1.10. EXERCISES 29

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-16.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-16.cpp -o /tmp/algorithm-design-manual-1-16
# /tmp/algorithm-design-manual-1-16

# %% [markdown]
# ## 1-17: Telescoping reciprocal induction proof
#
# ### Problem Statement
#
# [3] Prove by induction that for n ≥ 1, n 1 n = i =1 i ( i + 1) n + 1

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-17.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-17.cpp -o /tmp/algorithm-design-manual-1-17
# /tmp/algorithm-design-manual-1-17

# %% [markdown]
# ## 1-18: Divisibility induction proof
#
# ### Problem Statement
#
# 3 [3] Prove by induction that n + 2 n is divisible by 3 for all n ≥ 0.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-18.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-18.cpp -o /tmp/algorithm-design-manual-1-18
# /tmp/algorithm-design-manual-1-18

# %% [markdown]
# ## 1-19: Tree edge-count induction proof
#
# ### Problem Statement
#
# [3] Prove by induction that a tree with n vertices has exactly n − 1 edges.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-19.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-19.cpp -o /tmp/algorithm-design-manual-1-19
# /tmp/algorithm-design-manual-1-19

# %% [markdown]
# ## 1-20: Sum of cubes identity proof
#
# ### Problem Statement
#
# [3] Prove by induction that the sum of the cubes of the first n positive integers is equal to the square of the sum of these integers, that is, n n 3 2 i = ( i ) i =1 i =1 Estimation

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-20.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-20.cpp -o /tmp/algorithm-design-manual-1-20
# /tmp/algorithm-design-manual-1-20

# %% [markdown]
# ## 1-21: Estimate owned and library pages
#
# ### Problem Statement
#
# [3] Do all the books you own total at least one million pages? How many total pages are stored in your school library?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-21.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-21.cpp -o /tmp/algorithm-design-manual-1-21
# /tmp/algorithm-design-manual-1-21

# %% [markdown]
# ## 1-22: Estimate textbook word count
#
# ### Problem Statement
#
# [3] How many words are there in this textbook?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-22.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-22.cpp -o /tmp/algorithm-design-manual-1-22
# /tmp/algorithm-design-manual-1-22

# %% [markdown]
# ## 1-23: Mental estimate for one million seconds
#
# ### Problem Statement
#
# [3] How many hours are one million seconds? How many days? Answer these questions by doing all arithmetic in your head.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-23.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-23.cpp -o /tmp/algorithm-design-manual-1-23
# /tmp/algorithm-design-manual-1-23

# %% [markdown]
# ## 1-24: Estimate US cities and towns
#
# ### Problem Statement
#
# [3] Estimate how many cities and towns there are in the United States.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-24.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-24.cpp -o /tmp/algorithm-design-manual-1-24
# /tmp/algorithm-design-manual-1-24

# %% [markdown]
# ## 1-25: Estimate Mississippi River outflow
#
# ### Problem Statement
#
# [3] Estimate how many cubic miles of water flow out of the mouth of the Mississippi River each day. Do not look up any supplemental facts. Describe all assumptions you made in arriving at your answer.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-25.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-25.cpp -o /tmp/algorithm-design-manual-1-25
# /tmp/algorithm-design-manual-1-25

# %% [markdown]
# ## 1-26: Estimate chain restaurant locations
#
# ### Problem Statement
#
# [3] How many Starbucks or McDonald’s locations are there in your country?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-26.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-26.cpp -o /tmp/algorithm-design-manual-1-26
# /tmp/algorithm-design-manual-1-26

# %% [markdown]
# ## 1-27: Estimate bathtub draining time
#
# ### Problem Statement
#
# [3] How long would it take to empty a bathtub with a drinking straw?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-27.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-27.cpp -o /tmp/algorithm-design-manual-1-27
# /tmp/algorithm-design-manual-1-27

# %% [markdown]
# ## 1-28: Estimate storage and CPU time scales
#
# ### Problem Statement
#
# [3] Is disk drive access time normally measured in milliseconds (thousandths of a second) or microseconds (millionths of a second)? Does your RAM memory access a word in more or less than a microsecond? How many instructions can your CPU execute in one year if the machine is left running all the time?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-28.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-28.cpp -o /tmp/algorithm-design-manual-1-28
# /tmp/algorithm-design-manual-1-28

# %% [markdown]
# ## 1-29: Compare sorting runtime growth
#
# ### Problem Statement
#
# [4] A sorting algorithm takes 1 second to sort 1,000 items on your machine. How long will it take to sort 10,000 items... (a) if you believe that the algorithm takes time proportional to 2 n, and (b) if you believe that the algorithm takes time roughly proportional to n log n ? Implementation Projects

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-29.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-29.cpp -o /tmp/algorithm-design-manual-1-29
# /tmp/algorithm-design-manual-1-29

# %% [markdown]
# ## 1-30: Implement and compare TSP heuristics
#
# ### Problem Statement
#
# [5] Implement the two TSP heuristics of Section 1.1 (page 5). Which of them gives better solutions in practice? Can you devise a heuristic that works better than both of them?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-30.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-30.cpp -o /tmp/algorithm-design-manual-1-30
# /tmp/algorithm-design-manual-1-30

# %% [markdown]
# ## 1-31: Implement Lotto coverage search
#
# ### Problem Statement
#
# [5] Describe how to test whether a given set of tickets establishes sufficient coverage in the Lotto problem of Section 1.8 (page 22). Write a program to find good ticket sets. 30 CHAPTER 1. INTRODUCTION TO ALGORITHM DESIGN Interview Problems

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-31.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-31.cpp -o /tmp/algorithm-design-manual-1-31
# /tmp/algorithm-design-manual-1-31

# %% [markdown]
# ## 1-32: Integer division without division or multiplication
#
# ### Problem Statement
#
# [5] Write a function to perform integer division without using either the / or * operators. Find a fast way to do it.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-32.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-32.cpp -o /tmp/algorithm-design-manual-1-32
# /tmp/algorithm-design-manual-1-32

# %% [markdown]
# ## 1-33: Minimum races for top three horses
#
# ### Problem Statement
#
# [5] There are twenty-five horses. At most, five horses can race together at a time. You must determine the fastest, second fastest, and third fastest horses. Find the minimum number of races in which this can be done.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-33.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-33.cpp -o /tmp/algorithm-design-manual-1-33
# /tmp/algorithm-design-manual-1-33

# %% [markdown]
# ## 1-34: Estimate worldwide piano tuners
#
# ### Problem Statement
#
# [3] How many piano tuners are there in the entire world?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-34.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-34.cpp -o /tmp/algorithm-design-manual-1-34
# /tmp/algorithm-design-manual-1-34

# %% [markdown]
# ## 1-35: Estimate US gas stations
#
# ### Problem Statement
#
# [3] How many gas stations are there in the United States?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-35.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-35.cpp -o /tmp/algorithm-design-manual-1-35
# /tmp/algorithm-design-manual-1-35

# %% [markdown]
# ## 1-36: Estimate hockey rink ice weight
#
# ### Problem Statement
#
# [3] How much does the ice in a hockey rink weigh?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-36.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-36.cpp -o /tmp/algorithm-design-manual-1-36
# /tmp/algorithm-design-manual-1-36

# %% [markdown]
# ## 1-37: Estimate US road mileage
#
# ### Problem Statement
#
# [3] How many miles of road are there in the United States?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-37.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-37.cpp -o /tmp/algorithm-design-manual-1-37
# /tmp/algorithm-design-manual-1-37

# %% [markdown]
# ## 1-38: Estimate random phone-book search attempts
#
# ### Problem Statement
#
# [3] On average, how many times would you have to flip open the Manhattan phone book at random in order to find a specific name?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/algorithm-design-manual-1-38.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/algorithm-design-manual-1-38.cpp -o /tmp/algorithm-design-manual-1-38
# /tmp/algorithm-design-manual-1-38
