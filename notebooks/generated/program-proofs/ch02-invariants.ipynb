# %% [markdown]
# # Program Proofs: Chapter 02 - Invariants
#
# Use this notebook for original notes, solutions, code experiments, and proof attempts. Keep copied textbook text out of committed cells.

# %% [markdown]
# ## Chapter Notes
#
# ### Main Ideas
#
# -
#
# ### Definitions
#
# | Term | Meaning |
# | --- | --- |
# | | |
#
# ### Open Questions
#
# -

# %% [markdown]
# ## 2.1: Add exercise title or short cue
#
# - Source: Program Proofs
# - Problem: 2.1
# - Kind: proof
# - Status: Not started
# - Tags: invariants
#
# ### Problem Reference
#
# Add a short reference or your own paraphrase. Do not paste copied problem text into committed notebooks.

# %% [markdown]
# ### Text Response
#
# Write the main reasoning, proof, or solution attempt here.

# %% [markdown]
# ### Python

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %% [markdown]
# ### C++

# %%
# %%bash
# cat > /tmp/program-proofs-2-1.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/program-proofs-2-1.cpp -o /tmp/program-proofs-2-1
# /tmp/program-proofs-2-1

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:
