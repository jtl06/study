# %% [markdown]
# # Operating Systems: Principles and Practice: Chapter 01 - Introduction
#
# Use this notebook for original notes, solutions, code experiments, and proof attempts. Keep copied textbook text out of committed cells.

# %% [markdown]
# ## Chapter Notes
#
# ### Main Ideas
#
# -
#
# ### Definitions
#
# | Term | Meaning |
# | --- | --- |
# | | |
#
# ### Open Questions
#
# -

# %% [markdown]
# ## 1: OS roles as referee illusionist and glue
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 1
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;concepts
#
# ### Problem Reference
#
# ![Problem 1 statement](../../problem-images.local/operating-systems-principles-practice/1.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-1.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-1.cpp -o /tmp/operating-systems-principles-practice-1
# /tmp/operating-systems-principles-practice-1

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 2: Compare core operating-systems terms
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 2
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;concepts
#
# ### Problem Reference
#
# ![Problem 2 statement](../../problem-images.local/operating-systems-principles-practice/2.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-2.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-2.cpp -o /tmp/operating-systems-principles-practice-2
# /tmp/operating-systems-principles-practice-2

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 3: Define direct memory access
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 3
# - Kind: exercise
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;hardware
#
# ### Problem Reference
#
# ![Problem 3 statement](../../problem-images.local/operating-systems-principles-practice/3.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-3.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-3.cpp -o /tmp/operating-systems-principles-practice-3
# /tmp/operating-systems-principles-practice-3

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 4: Resource allocation without fault isolation
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 4
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;resource-management
#
# ### Problem Reference
#
# ![Problem 4 statement](../../problem-images.local/operating-systems-principles-practice/4.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-4.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-4.cpp -o /tmp/operating-systems-principles-practice-4
# /tmp/operating-systems-principles-practice-4

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 5: Hardware and OS support for fault isolation
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 5
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;isolation;security
#
# ### Problem Reference
#
# ![Problem 5 statement](../../problem-images.local/operating-systems-principles-practice/5.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-5.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-5.cpp -o /tmp/operating-systems-principles-practice-5
# /tmp/operating-systems-principles-practice-5

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 6: Inter-application communication design
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 6
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;communication
#
# ### Problem Reference
#
# ![Problem 6 statement](../../problem-images.local/operating-systems-principles-practice/6.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-6.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-6.cpp -o /tmp/operating-systems-principles-practice-6
# /tmp/operating-systems-principles-practice-6

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 7: Design a virtual memory illusion
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 7
# - Kind: design
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;virtual-memory
#
# ### Problem Reference
#
# ![Problem 7 statement](../../problem-images.local/operating-systems-principles-practice/7.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-7.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-7.cpp -o /tmp/operating-systems-principles-practice-7
# /tmp/operating-systems-principles-practice-7

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 8: Run an OS as an application
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 8
# - Kind: design
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;virtualization
#
# ### Problem Reference
#
# ![Problem 8 statement](../../problem-images.local/operating-systems-principles-practice/8.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-8.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-8.cpp -o /tmp/operating-systems-principles-practice-8
# /tmp/operating-systems-principles-practice-8

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 9: Crash-consistent disk update design
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 9
# - Kind: design
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;storage;reliability
#
# ### Problem Reference
#
# ![Problem 9 statement](../../problem-images.local/operating-systems-principles-practice/9.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-9.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-9.cpp -o /tmp/operating-systems-principles-practice-9
# /tmp/operating-systems-principles-practice-9

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 10: Government resource management analogy
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 10
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;resource-management
#
# ### Problem Reference
#
# ![Problem 10 statement](../../problem-images.local/operating-systems-principles-practice/10.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-10.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-10.cpp -o /tmp/operating-systems-principles-practice-10
# /tmp/operating-systems-principles-practice-10

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 11: Ultra-reliable operating system design
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 11
# - Kind: design
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;reliability
#
# ### Problem Reference
#
# ![Problem 11 statement](../../problem-images.local/operating-systems-principles-practice/11.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-11.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-11.cpp -o /tmp/operating-systems-principles-practice-11
# /tmp/operating-systems-principles-practice-11

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 12: Reboot time and availability techniques
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 12
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;availability
#
# ### Problem Reference
#
# ![Problem 12 statement](../../problem-images.local/operating-systems-principles-practice/12.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-12.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-12.cpp -o /tmp/operating-systems-principles-practice-12
# /tmp/operating-systems-principles-practice-12

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:

# %% [markdown]
# ## 13: Prioritize OS design goals for current computer
#
# - Source: Operating Systems: Principles and Practice v1 PDF
# - Problem: 13
# - Kind: discussion
# - Status: Not started
# - Page/ref: Chapter 1 Exercises
# - Tags: os;tradeoffs
#
# ### Problem Reference
#
# ![Problem 13 statement](../../problem-images.local/operating-systems-principles-practice/13.svg)

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-13.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-13.cpp -o /tmp/operating-systems-principles-practice-13
# /tmp/operating-systems-principles-practice-13

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:
