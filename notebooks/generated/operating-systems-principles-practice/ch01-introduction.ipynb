# %% [markdown]
# # Operating Systems: Principles and Practice: Chapter 01 - Introduction
#
# Use this notebook for notes, solutions, code experiments, and proof attempts.

# %% [markdown]
# ## Chapter Notes
#
# ### Main Ideas
#
# -
#
# ### Definitions
#
# | Term | Meaning |
# | --- | --- |
# | | |
#
# ### Open Questions
#
# -

# %% [markdown]
# ## 1: OS roles as referee illusionist and glue
#
# ### Problem Statement
#
# What is an example of an operating system as: a. Referee? b. Illusionist? c. Glue?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-1.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-1.cpp -o /tmp/operating-systems-principles-practice-1
# /tmp/operating-systems-principles-practice-1

# %% [markdown]
# ## 2: Compare core operating-systems terms
#
# ### Problem Statement
#
# What is the difference, if any, between the following terms: a. Reliability vs. availability? b. Security vs. privacy? c. Security enforcement vs. security policy? d. Throughput vs. response time? e. Efficiency vs. overhead? f. Application programming interface (API) vs. abstract virtual machine (AVM)? g. Abstract virtual machine (AVM) vs. hardware abstraction layer (HAL)? h. Proprietary vs. open operating system? i. Batch vs. interactive operating system? j. Host vs. guest operating system?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-2.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-2.cpp -o /tmp/operating-systems-principles-practice-2
# /tmp/operating-systems-principles-practice-2

# %% [markdown]
# ## 3: Define direct memory access
#
# ### Problem Statement
#
# Define the term, direct memory access (DMA). For the following questions, take a moment to speculate. We provide answers to these questions throughout the book, but, given what you know now, how would you answer them? Before there were operating systems, someone needed to develop solutions without being able to look them up! How would you have designed the first operating system?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-3.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-3.cpp -o /tmp/operating-systems-principles-practice-3
# /tmp/operating-systems-principles-practice-3

# %% [markdown]
# ## 4: Resource allocation without fault isolation
#
# ### Problem Statement
#
# Suppose a computer system and all of its applications were completely bug free. Suppose further that everyone in the world were completely honest and trustworthy. In other words, we need not consider fault isolation. a. How should an operating system allocate time on the processor? Should it give the entire processor to each application until it no longer needs it? If there were multiple tasks ready to go at the same time, should it schedule first the task with the least amount of work to do or the one with the most? Justify your answer. b. How should the operating system allocate physical memory to applications? What should happen if the set of applications does not fit in memory at the same time? c. How should the operating system allocate its disk space? Should the first user to ask acquire all of the free space? What would the likely outcome be for that policy?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-4.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-4.cpp -o /tmp/operating-systems-principles-practice-4
# /tmp/operating-systems-principles-practice-4

# %% [markdown]
# ## 5: Hardware and OS support for fault isolation
#
# ### Problem Statement
#
# Now suppose the computer system needs to support fault isolation. What hardware and/or operating support do you think would be needed to do the following? a. Protect an application’s data structures in memory from being corrupted by other applications. b. Protecting one user’s disk files from being accessed or corrupted by another user. c. Protecting the network from a virus trying to use your computer to send spam.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-5.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-5.cpp -o /tmp/operating-systems-principles-practice-5
# /tmp/operating-systems-principles-practice-5

# %% [markdown]
# ## 6: Inter-application communication design
#
# ### Problem Statement
#
# How should an operating system support communication between applications? Explain your reasoning. a. Through the file system? b. Through messages passed between applications? c. Through regions of memory shared between the applications? d. All of the above? e. None of the above?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-6.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-6.cpp -o /tmp/operating-systems-principles-practice-6
# /tmp/operating-systems-principles-practice-6

# %% [markdown]
# ## 7: Design a virtual memory illusion
#
# ### Problem Statement
#
# How would you design combined hardware and software support to provide the illusion of a nearly infinite virtual memory on a limited amount of physical memory?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-7.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-7.cpp -o /tmp/operating-systems-principles-practice-7
# /tmp/operating-systems-principles-practice-7

# %% [markdown]
# ## 8: Run an OS as an application
#
# ### Problem Statement
#
# How would you design a system to run an entire operating system as an application on top of another operating system?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-8.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-8.cpp -o /tmp/operating-systems-principles-practice-8
# /tmp/operating-systems-principles-practice-8

# %% [markdown]
# ## 9: Crash-consistent disk update design
#
# ### Problem Statement
#
# How would you design a system to update complex data structures on disk in a consistent fashion despite machine crashes?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-9.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-9.cpp -o /tmp/operating-systems-principles-practice-9
# /tmp/operating-systems-principles-practice-9

# %% [markdown]
# ## 10: Government resource management analogy
#
# ### Problem Statement
#
# Society itself must grapple with managing resources. What ways do governments use to allocate resources, isolate misuse, and foster sharing in real life?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-10.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-10.cpp -o /tmp/operating-systems-principles-practice-10
# /tmp/operating-systems-principles-practice-10

# %% [markdown]
# ## 11: Ultra-reliable operating system design
#
# ### Problem Statement
#
# Suppose you were tasked with designing and implementing an ultra-reliable and ultra-available operating system. What techniques would you use? What tests, if any, might be sufficient to convince you of the system’s reliability, short of handing your operating system to millions of users to serve as beta testers?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-11.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-11.cpp -o /tmp/operating-systems-principles-practice-11
# /tmp/operating-systems-principles-practice-11

# %% [markdown]
# ## 12: Reboot time and availability techniques
#
# ### Problem Statement
#
# MTTR, and therefore availability, can be improved by reducing the time to reboot a system after a failure. What techniques might you use to speed up booting? Would your techniques always work after a failure?

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-12.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-12.cpp -o /tmp/operating-systems-principles-practice-12
# /tmp/operating-systems-principles-practice-12

# %% [markdown]
# ## 13: Prioritize OS design goals for current computer
#
# ### Problem Statement
#
# For the computer you are currently using, how should the operating system designers prioritize among reliability, security, portability, performance, and adoption? Explain why.

# %% [markdown]
# Write the main reasoning, proof, notes, or solution attempt here.

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-13.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-13.cpp -o /tmp/operating-systems-principles-practice-13
# /tmp/operating-systems-principles-practice-13
