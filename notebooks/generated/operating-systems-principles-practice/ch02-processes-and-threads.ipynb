# %% [markdown]
# # Operating Systems: Principles and Practice: Chapter 02 - Processes and Threads
#
# Use this notebook for original notes, solutions, code experiments, and proof attempts. Keep copied textbook text out of committed cells.

# %% [markdown]
# ## Chapter Notes
#
# ### Main Ideas
#
# -
#
# ### Definitions
#
# | Term | Meaning |
# | --- | --- |
# | | |
#
# ### Open Questions
#
# -

# %% [markdown]
# ## 2.1: Add exercise title or short cue
#
# - Source: Operating Systems: Principles and Practice
# - Problem: 2.1
# - Kind: exercise
# - Status: Not started
# - Tags: processes;threads
#
# ### Problem Reference
#
# Add a short reference or your own paraphrase. Do not paste copied problem text into committed notebooks.

# %% [markdown]
# ### Markdown Response
#
# Write the main reasoning, proof, notes, or solution attempt here.

# %% [markdown]
# ### Python

# %%
# Python scratch / solution cell.

def solve():
    pass


if __name__ == "__main__":
    solve()

# %% [markdown]
# ### C++

# %%
# %%bash
# cat > /tmp/operating-systems-principles-practice-2-1.cpp <<'CPP'
# #include <bits/stdc++.h>
# using namespace std;
#
# int main() {
#     ios::sync_with_stdio(false);
#     cin.tie(nullptr);
#
#     return 0;
# }
# CPP
# g++ -std=c++20 -O2 -Wall -Wextra -pedantic /tmp/operating-systems-principles-practice-2-1.cpp -o /tmp/operating-systems-principles-practice-2-1
# /tmp/operating-systems-principles-practice-2-1

# %% [markdown]
# ### Verification and Reflection
#
# - Checks performed:
# - Mistakes or revisions:
# - Follow-up:
